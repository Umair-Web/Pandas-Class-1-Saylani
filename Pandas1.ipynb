# %%
import pandas as pd

# %%
# CSV Comma separated values.
data=pd.read_csv(r"C:\Users\smit\Downloads\noble.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 # CSV Comma separated values.
# ----> 2 data=pd.read_csv(r"C:\Users\smit\Downloads\noble.csv")
#
# ...

# %%
data = pd.read_excel(r"C:\Users\smit\Downloads\nobel.xlsx")
data.head(10)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
# 5  1901     Physics                 The Nobel Prize in Physics 1901
# 6  1902   Chemistry               The Nobel Prize in Chemistry 1902
# 7  1902  Literature              The Nobel Prize in Literature 1902
# 8  1902    Medicine  The Nobel Prize in Physiology or Medicine 1902
# 9  1902       Peace                      The Nobel Peace Prize 1902
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...  2024-01-01          160
# ...

# %%
#last 5 rows
data.tail()
# Out:
#      year    category                                              prize  \
# 995  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 996  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 997  2023  Literature                 The Nobel Prize in Literature 2023
# 998  2023       Peace                         The Nobel Peace Prize 2023
# 999  2023   Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# 995  "for the discovery and synthesis of quantum dots"  2024-01-03
# 996  "for the discovery and synthesis of quantum dots"  2024-01-03
# 997  "for his innovative plays and prose which give...  2024-01-01
# 998  "for her fight against the oppression of women...  2024-01-01
# 999  "for having advanced our understanding of wome...  2024-01-01
#
#      laureate_id laureate_type         full_name           birth_date  \
# ...

# %%
#Checking dataset.
#To check rows and columns.
print(data.shape)
# Out:
# (1000, 18)

# %%
#Checking dataset.
#To check cloumns only.
print(data.shape[1])
# Out:
# 18

# %%
#To check column 
print(data.columns)
# Out:
# Index(['year', 'category', 'prize', 'motivation', 'prize_share', 'laureate_id',
#        'laureate_type', 'full_name', 'birth_date', 'birth_city',
#        'birth_country', 'sex', 'organization_name', 'organization_city',
#        'organization_country', 'death_date', 'death_city', 'death_country'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  1000 non-null   int64
#  1   category              1000 non-null   object
#  2   prize                 1000 non-null   object
#  3   motivation            912 non-null    object
#  4   prize_share           1000 non-null   datetime64[ns]
#  5   laureate_id           1000 non-null   int64
#  6   laureate_type         1000 non-null   object
#  7   full_name             1000 non-null   object
#  8   birth_date            968 non-null    object
#  9   birth_city            964 non-null    object
#  10  birth_country         969 non-null    object
#  11  sex                   970 non-null    object
#  12  organization_name     736 non-null    object
#  13  organization_city     735 non-null    object
#  14  organization_country  735 non-null    object
# ...

# %%
#stats Description
data.describe()
# Out:
#               year                    prize_share  laureate_id  \
# count  1000.000000                           1000  1000.000000
# mean   1973.721000  2024-01-02 00:38:52.800000256   509.099000
# min    1901.000000            2024-01-01 00:00:00     1.000000
# 25%    1949.750000            2024-01-01 00:00:00   250.750000
# 50%    1979.000000            2024-01-02 00:00:00   500.500000
# 75%    2003.000000            2024-01-03 00:00:00   764.250000
# max    2023.000000            2024-01-04 00:00:00  1034.000000
# std      34.523195                            NaN   298.130617
#
#                           death_date
# count                            596
# mean   1975-02-14 13:48:43.489932896
# min              1903-11-01 00:00:00
# 25%              1954-02-15 12:00:00
# 50%              1980-03-09 12:00:00
# 75%              2000-01-05 00:00:00
# max              2023-10-13 00:00:00
# std                              NaN

# %%
#Categorical
data.describe(include="all")
